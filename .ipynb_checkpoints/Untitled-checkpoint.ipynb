# %%
# %matplotlib inline

import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import os

from IPython.display import display

# %%
filename = 'jogos.xlsx'
if filename in os.listdir():
    print(f'Encontrei o arquivo {filename}, tudo certo para prosseguir com a prova!')
else:
    print(f'Não encontrei o arquivo {filename} aqui no diretório {os.getcwd()}, será que você não baixou o arquivo?')
# Out:
# Encontrei o arquivo jogos.xlsx, tudo certo para prosseguir com a prova!

# %%
jogos_Tain = pd.read_excel(filename)
jogos.head(5)
# Out:
#                                                 Name  Metacritic  \
# 0                              Mitsurugi Kamui Hikae         NaN
# 1                                            Warcube         NaN
# 2  Adventures of Bertram Fiddle: Episode 1: A Dre...         NaN
# 3                        Supreme Ruler The Great War         NaN
# 4                                  PixelJunk Shooter       730.0
#
#                                         Genres  Indie  Presence  \
# 0                                Action, Indie   10.0  118470.0
# 1  Action, Adventure, Indie, RPG, Early Access   10.0    3370.0
# 2                     Adventure, Casual, Indie   10.0   13440.0
# 3                  Indie, Simulation, Strategy   10.0    3810.0
# 4                                       Action   10.0  575520.0
#
#                                             Platform                  Storage  \
# 0       PC, Xbox One, PlayStation 4, Nintendo Switch   200 MB available space
# 1                                          PC, macOS  1500 MB available space
# 2  Android, iOS, PC, macOS, Xbox One, Nintendo Sw...     1 GB available space
# 3                                          macOS, PC     2 GB available space
# 4                    Linux, PC, macOS, PlayStation 3   250 MB available space
#
#   OriginalCost             Players  \
# 0        $9.99        singleplayer
# 1        $9.99         multiplayer
# 2        $4.99        singleplayer
# 3       $19.99         multiplayer
# 4        $8.99  singleplayer, coop
#
#                                     Languages          ESRB  Achievements
# 0                   English, Japanese, Korean           NaN         920.0
# 1                                     English           NaN           0.0
# 2          English, Japanese, Russian, German          Teen          80.0
# 3                     English, French, German      Everyone           0.0
# 4  English, French, Italian, German, Japanese  Everyone 10+         280.0

# %%
jogos_test=pd.read_excel(filename,sheet_name = 'test')
jogos_test.head(5)
# Out:
#                                Name  Metacritic  \
# 0  Counter-Strike: Global Offensive       830.0
# 1                         Destiny 2       820.0
# 2                            Dota 2       900.0
# 3          The Elder Scrolls Online       710.0
# 4                    Sea of Thieves       680.0
#
#                             Genres  Indie    Presence  \
# 0             Action, Free to Play    0.0  10095880.0
# 1  Action, Adventure, Free to Play    0.0  10074250.0
# 2                              NaN    0.0  10093060.0
# 3       Massively Multiplayer, RPG    0.0  10007810.0
# 4                Action, Adventure    0.0   7774560.0
#
#                                             Platform                 Storage  \
# 0                        PC, Xbox 360, PlayStation 3   15 GB available space
# 1  PlayStation 5, Web, Xbox Series X, PC, Xbox On...  105 GB available space
# 2                                   Linux, macOS, PC   15 GB available space
# 3                                                 PC   85 GB available space
# 4                                       PC, Xbox One   50 GB available space
#
#    OriginalCost                              Players  \
# 0  Free to Play  multiplayer, pvp, coop, online coop
# 1  Free To Play       multiplayer, coop, online coop
# 2  Free to Play  multiplayer, pvp, coop, online coop
# 3        $19.99      singleplayer, multiplayer, coop
# 4        $39.99  multiplayer, pvp, coop, online coop
#
#                                            Languages    ESRB  Achievements  \
# 0  English, Czech, Danish, Dutch, Finnish, French...  Mature        1790.0
# 1  English, French, Italian, German, Japanese, Ko...    Teen         610.0
# 2  English, Bulgarian, Czech, Danish, Dutch, Finn...     NaN           0.0
# 3                   English, French, German, Russian     NaN           0.0
# 4          English, French, Italian, German, Russian    Teen        3080.0
#
#    Column1
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
